# %%
from itertools import product
alphabet="агмнсту"

# %%
list(product(alphabet,repeat=3))
# Out:
# [('а', 'а', 'а'),
#  ('а', 'а', 'г'),
#  ('а', 'а', 'м'),
#  ('а', 'а', 'н'),
#  ('а', 'а', 'с'),
#  ('а', 'а', 'т'),
#  ('а', 'а', 'у'),
#  ('а', 'г', 'а'),
#  ('а', 'г', 'г'),
#  ('а', 'г', 'м'),
#  ('а', 'г', 'н'),
#  ('а', 'г', 'с'),
#  ('а', 'г', 'т'),
#  ('а', 'г', 'у'),
#  ('а', 'м', 'а'),
#  ('а', 'м', 'г'),
#  ('а', 'м', 'м'),
#  ('а', 'м', 'н'),
#  ('а', 'м', 'с'),
#  ('а', 'м', 'т'),
#  ('а', 'м', 'у'),
#  ('а', 'н', 'а'),
#  ('а', 'н', 'г'),
#  ('а', 'н', 'м'),
#  ('а', 'н', 'н'),
#  ('а', 'н', 'с'),
#  ('а', 'н', 'т'),
#  ('а', 'н', 'у'),
#  ('а', 'с', 'а'),
#  ('а', 'с', 'г'),
#  ('а', 'с', 'м'),
#  ('а', 'с', 'н'),
#  ('а', 'с', 'с'),
#  ('а', 'с', 'т'),
#  ('а', 'с', 'у'),
#  ('а', 'т', 'а'),
#  ('а', 'т', 'г'),
#  ('а', 'т', 'м'),
#  ('а', 'т', 'н'),
#  ('а', 'т', 'с'),
#  ('а', 'т', 'т'),
#  ('а', 'т', 'у'),
#  ('а', 'у', 'а'),
#  ('а', 'у', 'г'),
#  ('а', 'у', 'м'),
#  ('а', 'у', 'н'),
#  ('а', 'у', 'с'),
#  ('а', 'у', 'т'),
#  ('а', 'у', 'у'),
#  ('г', 'а', 'а'),
# ...

# %%
alphabet="агмнсту"
count=0

for l1 in alphabet:
    for l2 in alphabet:
        for l3 in alphabet:
            for l4 in alphabet:
                for l5 in alphabet:
                    for l6 in alphabet:
                        word=l1+l2+l3+l4+l5+l6
                        if word[0]!="у" and word.count("м")==2  and word.count("г")<=1:
                            print(word)

# %%
for a, b, c in [(1,1,1),(2,2,2),(3,3,3)]:
    print(a, b, c)
# Out:
# 1 1 1
# 2 2 2
# 3 3 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "8" * 68

# %%
s.replace("888","2",1)
# Out:
# '88888888888888888888888888888888888888888888888888888888888888888888'

# %%
sum(int(s) for s in "12345")
# Out:
# 15
